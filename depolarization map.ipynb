# %% [markdown]
# <a href="https://colab.research.google.com/github/Vani2130/Quantum-computing/blob/main/depolarization%20map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import sympy as sp

def partial_transpose(rho, dimA, dimB):
    """
    Calculate the partial transpose of a density matrix `rho` with respect to the first subsystem.

    Parameters:
    rho (sympy.Matrix): Density matrix of the bipartite system.
    dimA (int): Dimension of the first subsystem.
    dimB (int): Dimension of the second subsystem.

    Returns:
    sympy.Matrix: Partially transposed density matrix.
    """
    # Convert the density matrix to a NumPy array and reshape it to a 4D tensor
    rho_tensor = np.array(rho).reshape((dimA, dimB, dimA, dimB))

    # Perform the partial transpose (transpose the first subsystem's indices)
    rho_pt_tensor = rho_tensor.transpose(0, 2, 1, 3)

    # Reshape back to the original 2D density matrix shape
    rho_pt = rho_pt_tensor.reshape((dimA*dimB, dimA*dimB))

    return sp.Matrix(rho_pt)

def depolarizing_map(rho, p):
    """
    Apply the depolarizing map to a density matrix `rho`.

    Parameters:
    rho (sympy.Matrix): Density matrix.
    p (float): Depolarizing probability.

    Returns:
    sympy.Matrix: Density matrix after applying the depolarizing map.
    """
    d = rho.shape[0]  # Dimension of the density matrix
    identity = sp.eye(d)  # Identity matrix of the same dimension
    return (1 - p) * rho + (p / d) * identity

# Define symbolic variables for an 8x8 matrix
symbols = sp.symbols(' '.join(f'A{i}{j}' for i in range(1, 9) for j in range(1, 9)))

# Create the 8x8 symbolic density matrix
rho = sp.Matrix(8, 8, symbols)

dimA = 2  # Dimension of the first subsystem (qubit A)
dimB = 4  # Dimension of the combined second subsystem (qubits B and C)

# Apply partial transpose with respect to qubit A
rho_pt = partial_transpose(rho, dimA, dimB)

# Apply depolarizing map to the partially transposed density matrix
p = sp.Rational(1, 4)  # Example depolarizing probability
rho_depolarized = depolarizing_map(rho_pt, p)

# Compute the eigenvalues of the depolarized matrix
eigenvalues = rho_depolarized.eigenvals()

print("Original density matrix:")
sp.pprint(rho)
print("\nPartially transposed density matrix:")
sp.pprint(rho_pt)
print("\nDensity matrix after applying the depolarizing map:")
sp.pprint(rho_depolarized)
print("\nEigenvalues of the depolarized matrix:")
sp.pprint(eigenvalues)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-8602bb406983> in <cell line: 59>()
#      57
#      58 # Compute the eigenvalues of the depolarized matrix
# ---> 59 eigenvalues = rho_depolarized.eigenvals()
#      60
#      61 print("Original density matrix:")
#
# /usr/local/lib/python3.10/dist-packages/sympy/matrices/matrices.py in eigenvals(self, error_when_incomplete, **flags)
#     374
#     375     def eigenvals(self, error_when_incomplete=True, **flags):
# --> 376         return _eigenvals(self, error_when_incomplete=error_when_incomplete, **flags)
#     377
#     378     def eigenvects(self, error_when_incomplete=True, iszerofunc=_iszero, **flags):
#
# /usr/local/lib/python3.10/dist-packages/sympy/matrices/eigen.py in _eigenvals(M, error_when_incomplete, simplify, multiple, rational, **flags)
#     171             M, error_when_incomplete=error_when_incomplete, simplify=simplify,
#     172             **flags)
# --> 173     return _eigenvals_dict(
#     174         M, error_when_incomplete=error_when_incomplete, simplify=simplify,
#     175         **flags)
#
# /usr/local/lib/python3.10/dist-packages/sympy/matrices/eigen.py in _eigenvals_dict(M, error_when_incomplete, simplify, **flags)
#     250             charpoly = block.charpoly(simplify=simplify)
#     251         else:
# --> 252             charpoly = block.charpoly()
#     253
#     254         eigs = roots(charpoly, multiple=False, **flags)
#
# /usr/local/lib/python3.10/dist-packages/sympy/matrices/matrices.py in charpoly(self, x, simplify)
#     117
#     118     def charpoly(self, x='lambda', simplify=_simplify):
# --> 119         return _charpoly(self, x=x, simplify=simplify)
#     120
#     121     def cofactor(self, i, j, method="berkowitz"):
#
# /usr/local/lib/python3.10/dist-packages/sympy/matrices/determinant.py in _charpoly(M, x, simplify)
#     412     x = uniquely_named_symbol(x, berk_vector, modify=lambda s: '_' + s)
#     413
# --> 414     return PurePoly([simplify(a) for a in berk_vector], x)
#     415
#     416
#
# /usr/local/lib/python3.10/dist-packages/sympy/matrices/determinant.py in <listcomp>(.0)
#     412     x = uniquely_named_symbol(x, berk_vector, modify=lambda s: '_' + s)
#     413
# --> 414     return PurePoly([simplify(a) for a in berk_vector], x)
#     415
#     416
#
# /usr/local/lib/python3.10/dist-packages/sympy/matrices/utilities.py in _simplify(expr)
#      70     """ Wrapper to avoid circular imports. """
#      71     from sympy.simplify.simplify import simplify
# ---> 72     return simplify(expr)
#
# /usr/local/lib/python3.10/dist-packages/sympy/simplify/simplify.py in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     642     expr = _bottom_up(expr, lambda w: getattr(w, 'normal', lambda: w)())
#     643     expr = Mul(*powsimp(expr).as_content_primitive())
# --> 644     _e = cancel(expr)
#     645     expr1 = shorter(_e, _mexpand(_e).cancel())  # issue 6829
#     646     expr2 = shorter(together(expr, deep=True), together(expr1, deep=True))
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/polytools.py in cancel(f, _signsimp, *gens, **args)
#    6857         if f.has(Piecewise):
#    6858             raise PolynomialError()
# -> 6859         R, (F, G) = sring((p, q), *gens, **args)
#    6860         if not R.ngens:
#    6861             if not isinstance(f, (tuple, Tuple)):
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/rings.py in sring(exprs, *symbols, **options)
#     161
#     162     # TODO: rewrite this so that it doesn't use expand() (see poly()).
# --> 163     reps, opt = _parallel_dict_from_expr(exprs, opt)
#     164
#     165     if opt.domain is None:
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/polyutils.py in _parallel_dict_from_expr(exprs, opt)
#     324     """Transform expressions into a multinomial form. """
#     325     if opt.expand is not False:
# --> 326         exprs = [ expr.expand() for expr in exprs ]
#     327
#     328     if any(expr.is_commutative is False for expr in exprs):
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/polyutils.py in <listcomp>(.0)
#     324     """Transform expressions into a multinomial form. """
#     325     if opt.expand is not False:
# --> 326         exprs = [ expr.expand() for expr in exprs ]
#     327
#     328     if any(expr.is_commutative is False for expr in exprs):
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      70         def wrapper(*args, **kwargs):
#      71             try:
# ---> 72                 retval = cfunc(*args, **kwargs)
#      73             except TypeError as e:
#      74                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/expr.py in expand(self, deep, modulus, power_base, power_exp, mul, log, multinomial, basic, **hints)
#    3680             if use_hint:
#    3681                 hint = '_eval_expand_' + hint
# -> 3682                 expr, hit = Expr._expand_hint(expr, hint, deep=deep, **hints)
#    3683
#    3684         while True:
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3613             sargs = []
#    3614             for arg in expr.args:
# -> 3615                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3616                 hit |= arghit
#    3617                 sargs.append(arg)
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3613             sargs = []
#    3614             for arg in expr.args:
# -> 3615                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3616                 hit |= arghit
#    3617                 sargs.append(arg)
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3613             sargs = []
#    3614             for arg in expr.args:
# -> 3615                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3616                 hit |= arghit
#    3617                 sargs.append(arg)
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3613             sargs = []
#    3614             for arg in expr.args:
# -> 3615                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3616                 hit |= arghit
#    3617                 sargs.append(arg)
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3613             sargs = []
#    3614             for arg in expr.args:
# -> 3615                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3616                 hit |= arghit
#    3617                 sargs.append(arg)
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3613             sargs = []
#    3614             for arg in expr.args:
# -> 3615                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3616                 hit |= arghit
#    3617                 sargs.append(arg)
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3613             sargs = []
#    3614             for arg in expr.args:
# -> 3615                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3616                 hit |= arghit
#    3617                 sargs.append(arg)
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3621
#    3622         if hasattr(expr, hint):
# -> 3623             newexpr = getattr(expr, hint)(**hints)
#    3624             if newexpr != expr:
#    3625                 return (newexpr, True)
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/mul.py in _eval_expand_mul(self, **hints)
#     952                         t = t._eval_expand_mul()
#     953                     args.append(t)
# --> 954                 return Add(*args)
#     955             else:
#     956                 return plain
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      70         def wrapper(*args, **kwargs):
#      71             try:
# ---> 72                 retval = cfunc(*args, **kwargs)
#      73             except TypeError as e:
#      74                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/operations.py in __new__(cls, evaluate, _sympify, *args)
#      96             return args[0]
#      97
# ---> 98         c_part, nc_part, order_symbols = cls.flatten(args)
#      99         is_commutative = not nc_part
#     100         obj = cls._from_args(c_part + nc_part, is_commutative)
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/add.py in flatten(cls, seq)
#     379
#     380         # order args canonically
# --> 381         _addsort(newseq)
#     382
#     383         # current code expects coeff to be first
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/add.py in _addsort(args)
#      36 def _addsort(args):
#      37     # in-place sorting of args
# ---> 38     args.sort(key=_args_sortkey)
#      39
#      40
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/basic.py in compare(self, other)
#     277             r = Basic(*r) if isinstance(r, frozenset) else r
#     278             if isinstance(l, Basic):
# --> 279                 c = l.compare(r)
#     280             else:
#     281                 c = (l > r) - (l < r)
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/basic.py in compare(self, other)
#     268             return c
#     269         #
# --> 270         st = self._hashable_content()
#     271         ot = other._hashable_content()
#     272         c = (len(st) > len(ot)) - (len(st) < len(ot))
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/symbol.py in _hashable_content(self)
#     361     def _hashable_content(self):
#     362         # Note: user-specified assumptions not hashed, just derived ones
# --> 363         return (self.name,) + tuple(sorted(self.assumptions0.items()))
#     364
#     365     def _eval_subs(self, old, new):
#
# KeyboardInterrupt:
